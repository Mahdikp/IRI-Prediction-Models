# %%
# Random Forest Regressor

# Importing the libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from scipy import stats
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
# Importing the dataset

dataset = pd.read_csv('all13.csv')
X = dataset.iloc[:,15:-1]
Y = dataset.iloc[:,25]
print(X)
# Out:
#       MILLING_CODE  IRI PREVIOUS  TIME PASSED SINCE LAST REHABILITATION  \
# 0                0          1.04                                   0.28
# 1                0          0.77                                   4.31
# 2                0          0.82                                   7.78
# 3                0          0.81                                   9.24
# 4                0          0.84                                  10.22
# ...            ...           ...                                    ...
# 2715             0          0.74                                   2.82
# 2716             0          0.75                                   3.93
# 2717             0          0.75                                   4.86
# 2718             0          0.85                                   8.04
# 2719             0          0.98                                   8.91
#
#       TOTAL_THICKNESS  OVERLAY_THICKNESS  TEMP_AVG  FREEZE_INDEX  \
# 0               553.8               48.3        18             0
# 1               553.8               48.3        18            15
# 2               553.8               48.3        20             4
# 3               553.8               48.3        19             1
# 4               553.8               48.3        20             0
# ...               ...                ...       ...           ...
# 2715            358.1               27.9         2          1512
# 2716            358.1               27.9         2          1866
# 2717            358.1               27.9         2          1966
# 2718            358.1               27.9         4          1486
# 2719            358.1               27.9         4          1229
#
#       PRECIPITATION  NUMBER OF PRESERVATION ACTIVITIES  EXTREME DECREASE
# 0              1439                                  0                 1
# 1              1394                                  0                 0
# 2               912                                  0                 0
# 3              1061                                  0                 0
# 4              1283                                  0                 0
# ...             ...                                ...               ...
# 2715            609                                  0                 0
# 2716            471                                  0                 0
# 2717            575                                  0                 0
# 2718            559                                  0                 0
# 2719            517                                  0                 0
#
# [2720 rows x 10 columns]

# %%
X.describe()
# Out:
#        MILLING_CODE  IRI PREVIOUS  TIME PASSED SINCE LAST REHABILITATION  \
# count   2720.000000   2720.000000                            2720.000000
# mean       0.560662      1.141838                               7.247614
# std        0.496398      0.493858                               5.192386
# min        0.000000      0.410000                               0.000000
# 25%        0.000000      0.820000                               2.890000
# 50%        1.000000      1.030000                               6.760000
# 75%        1.000000      1.320000                              10.792500
# max        1.000000      5.670000                              27.330000
#
#        TOTAL_THICKNESS  OVERLAY_THICKNESS     TEMP_AVG  FREEZE_INDEX  \
# count      2720.000000        2720.000000  2720.000000   2720.000000
# mean        670.389632          61.142279    13.583088    308.409191
# std         265.134566          31.935831     6.452794    455.999664
# min         203.200000           2.500000     2.000000      0.000000
# 25%         505.400000          40.600000     8.000000      0.000000
# 50%         631.100000          50.800000    13.000000     65.000000
# 75%         820.400000          71.100000    19.000000    442.000000
# max        2578.100000         177.800000    25.000000   2018.000000
#
#        PRECIPITATION  NUMBER OF PRESERVATION ACTIVITIES  EXTREME DECREASE
# count    2720.000000                        2720.000000       2720.000000
# mean      907.692647                           1.047794          0.127574
# std       475.735804                           1.051066          0.333676
# min        12.000000                           0.000000          0.000000
# 25%       581.500000                           0.000000          0.000000
# 50%       912.000000                           1.000000          0.000000
# 75%      1287.250000                           1.000000          0.000000
# max      2386.000000                           8.000000          1.000000

# %%
dataset.head()
# Out:
#   VISIT_NO  STATE_CODE STATE_CODE_EXP SHRP_ID  CONSTRUCTION_NO VISIT_DATE  \
# 0  1050202           1        Alabama     502                2   4/1/1992
# 1  1050204           1        Alabama     502                2  4/11/1996
# 2  1050205           1        Alabama     502                2  9/29/1999
# 3  1050206           1        Alabama     502                2  3/13/2001
# 4  1050207           1        Alabama     502                2   3/8/2002
#
#    YEAR  MERRA_ID    IMP_DATE                               IMP_TYPE_EXP  ...  \
# 0  1992    133784  12/20/1991  Hot-Mix Recycled Asphalt Concrete Overlay  ...
# 1  1996    133784  12/20/1991  Hot-Mix Recycled Asphalt Concrete Overlay  ...
# 2  1999    133784  12/20/1991  Hot-Mix Recycled Asphalt Concrete Overlay  ...
# 3  2001    133784  12/20/1991  Hot-Mix Recycled Asphalt Concrete Overlay  ...
# 4  2002    133784  12/20/1991  Hot-Mix Recycled Asphalt Concrete Overlay  ...
#
#   IRI PREVIOUS TIME PASSED SINCE LAST REHABILITATION  TOTAL_THICKNESS  \
# 0         1.04                                  0.28            553.8
# 1         0.77                                  4.31            553.8
# 2         0.82                                  7.78            553.8
# 3         0.81                                  9.24            553.8
# 4         0.84                                 10.22            553.8
#
#    OVERLAY_THICKNESS  TEMP_AVG  FREEZE_INDEX  PRECIPITATION  \
# 0               48.3        18             0           1439
# 1               48.3        18            15           1394
# 2               48.3        20             4            912
# 3               48.3        19             1           1061
# 4               48.3        20             0           1283
#
#    NUMBER OF PRESERVATION ACTIVITIES  EXTREME DECREASE   IRI
# 0                                  0                 1  0.77
# 1                                  0                 0  0.82
# 2                                  0                 0  0.81
# 3                                  0                 0  0.84
# 4                                  0                 0  0.84
#
# [5 rows x 26 columns]

# %%
dataset.tail()
# Out:
#       VISIT_NO  STATE_CODE STATE_CODE_EXP SHRP_ID  CONSTRUCTION_NO VISIT_DATE  \
# 2715  90B31004          90   Saskatchewan    B310                2  6/12/1993
# 2716  90B31005          90   Saskatchewan    B310                2  7/19/1994
# 2717  90B31007          90   Saskatchewan    B310                2  6/24/1995
# 2718  90B31009          90   Saskatchewan    B310                2  8/28/1998
# 2719  90B31010          90   Saskatchewan    B310                2  7/11/1999
#
#       YEAR  MERRA_ID   IMP_DATE              IMP_TYPE_EXP  ... IRI PREVIOUS  \
# 2715  1993    157945  8/16/1990  Asphalt Concrete Overlay  ...         0.74
# 2716  1994    157945  8/16/1990  Asphalt Concrete Overlay  ...         0.75
# 2717  1995    157945  8/16/1990  Asphalt Concrete Overlay  ...         0.75
# 2718  1998    157945  8/16/1990  Asphalt Concrete Overlay  ...         0.85
# 2719  1999    157945  8/16/1990  Asphalt Concrete Overlay  ...         0.98
#
#      TIME PASSED SINCE LAST REHABILITATION  TOTAL_THICKNESS  \
# 2715                                  2.82            358.1
# 2716                                  3.93            358.1
# 2717                                  4.86            358.1
# 2718                                  8.04            358.1
# 2719                                  8.91            358.1
#
#       OVERLAY_THICKNESS  TEMP_AVG  FREEZE_INDEX  PRECIPITATION  \
# 2715               27.9         2          1512            609
# 2716               27.9         2          1866            471
# 2717               27.9         2          1966            575
# 2718               27.9         4          1486            559
# 2719               27.9         4          1229            517
#
#       NUMBER OF PRESERVATION ACTIVITIES  EXTREME DECREASE   IRI
# 2715                                  0                 0  0.75
# 2716                                  0                 0  0.75
# 2717                                  0                 0  0.85
# 2718                                  0                 0  0.98
# 2719                                  0                 0  0.99
#
# [5 rows x 26 columns]

# %%
# Splitting the dataset into the Training set and Test set

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 47)
x2 = X_train.copy()
ds1 = pd.DataFrame(data=x2)
ds1['IRIF'] = list(Y_train)

# %%
# create regressor object

regressor = RandomForestRegressor(n_estimators=1000)

# %%
# fit the regressor with x and y data

regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
# test the output by changing values

Y_pred = regressor.predict(X_test)
x1 = X_test.copy()
ds2 = pd.DataFrame(data=x1)
ds2['IRIF'] = list(Y_pred)
ds2.to_csv('Ypredicted.csv')

# %%
# R2 & RMSE

MSE = mean_squared_error(Y_test, Y_pred)
RMSE = math.sqrt(MSE)
R2=r2_score(Y_test,Y_pred)
print("R2:\n", round(R2,3))
print("\n")
print("Root Mean Square Error:\n", round(RMSE,3))
print("\n")
print("Mean Square Error:\n", round(MSE,3))
# Out:
# R2:
#  0.913
#
#
# Root Mean Square Error:
#  0.125
#
#
# Mean Square Error:
#  0.016

# %%
# Correlation Matrix

matrix = ds1.corr()
matrix
# Out:
#                                        MILLING_CODE  IRI PREVIOUS  \
# MILLING_CODE                               1.000000     -0.131530
# IRI PREVIOUS                              -0.131530      1.000000
# TIME PASSED SINCE LAST REHABILITATION      0.069017     -0.070673
# TOTAL_THICKNESS                            0.097743     -0.092672
# OVERLAY_THICKNESS                          0.204381     -0.055229
# TEMP_AVG                                   0.293635     -0.158576
# FREEZE_INDEX                              -0.206405      0.154878
# PRECIPITATION                             -0.109754     -0.089785
# NUMBER OF PRESERVATION ACTIVITIES          0.077688      0.057416
# EXTREME DECREASE                          -0.001610      0.428017
# IRIF                                      -0.164688      0.639140
#
#                                        TIME PASSED SINCE LAST REHABILITATION  \
# MILLING_CODE                                                        0.069017
# IRI PREVIOUS                                                       -0.070673
# TIME PASSED SINCE LAST REHABILITATION                               1.000000
# TOTAL_THICKNESS                                                     0.100589
# OVERLAY_THICKNESS                                                   0.048000
# TEMP_AVG                                                            0.160090
# FREEZE_INDEX                                                       -0.108312
# PRECIPITATION                                                       0.035023
# NUMBER OF PRESERVATION ACTIVITIES                                   0.308997
# EXTREME DECREASE                                                   -0.466791
# IRIF                                                                0.277601
#
#                                        TOTAL_THICKNESS  OVERLAY_THICKNESS  \
# MILLING_CODE                                  0.097743           0.204381
# IRI PREVIOUS                                 -0.092672          -0.055229
# TIME PASSED SINCE LAST REHABILITATION         0.100589           0.048000
# TOTAL_THICKNESS                               1.000000          -0.040322
# OVERLAY_THICKNESS                            -0.040322           1.000000
# TEMP_AVG                                      0.004396          -0.052529
# FREEZE_INDEX                                 -0.010826           0.043944
# PRECIPITATION                                 0.241398          -0.399418
# NUMBER OF PRESERVATION ACTIVITIES            -0.130365           0.192469
# EXTREME DECREASE                             -0.055765          -0.069773
# IRIF                                         -0.098535          -0.056438
#
#                                        TEMP_AVG  FREEZE_INDEX  PRECIPITATION  \
# MILLING_CODE                           0.293635     -0.206405      -0.109754
# IRI PREVIOUS                          -0.158576      0.154878      -0.089785
# TIME PASSED SINCE LAST REHABILITATION  0.160090     -0.108312       0.035023
# TOTAL_THICKNESS                        0.004396     -0.010826       0.241398
# OVERLAY_THICKNESS                     -0.052529      0.043944      -0.399418
# TEMP_AVG                               1.000000     -0.828039      -0.061919
# FREEZE_INDEX                          -0.828039      1.000000      -0.067357
# PRECIPITATION                         -0.061919     -0.067357       1.000000
# NUMBER OF PRESERVATION ACTIVITIES     -0.017341      0.031357      -0.121363
# EXTREME DECREASE                       0.009735     -0.023856       0.062772
# IRIF                                  -0.165506      0.158985      -0.128853
#
#                                        NUMBER OF PRESERVATION ACTIVITIES  \
# MILLING_CODE                                                    0.077688
# IRI PREVIOUS                                                    0.057416
# TIME PASSED SINCE LAST REHABILITATION                           0.308997
# TOTAL_THICKNESS                                                -0.130365
# OVERLAY_THICKNESS                                               0.192469
# TEMP_AVG                                                       -0.017341
# FREEZE_INDEX                                                    0.031357
# PRECIPITATION                                                  -0.121363
# NUMBER OF PRESERVATION ACTIVITIES                               1.000000
# EXTREME DECREASE                                               -0.143805
# IRIF                                                            0.183003
#
#                                        EXTREME DECREASE      IRIF
# MILLING_CODE                                  -0.001610 -0.164688
# IRI PREVIOUS                                   0.428017  0.639140
# TIME PASSED SINCE LAST REHABILITATION         -0.466791  0.277601
# TOTAL_THICKNESS                               -0.055765 -0.098535
# OVERLAY_THICKNESS                             -0.069773 -0.056438
# TEMP_AVG                                       0.009735 -0.165506
# FREEZE_INDEX                                  -0.023856  0.158985
# PRECIPITATION                                  0.062772 -0.128853
# NUMBER OF PRESERVATION ACTIVITIES             -0.143805  0.183003
# EXTREME DECREASE                               1.000000 -0.178244
# IRIF                                          -0.178244  1.000000

# %%
# Plot

slope, intercept, r, p, std_err = stats.linregress(Y_test, Y_pred)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, Y_test))

plt.scatter(Y_test, Y_pred)
plt.plot(Y_test, mymodel, color = "r")
plt.xlabel("Actual")
plt.ylabel("RF_Predictions")
plt.title(f"R2 : {round(R2,2)} \n RMSE : {round(RMSE,3)} ")
plt.show()
