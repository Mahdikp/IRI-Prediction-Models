# %%
import numpy as np
import pandas as pd

o1 = pd.read_csv('M3.csv')
o2 = pd.read_csv('esal.csv')

df1 = pd.DataFrame(o1,columns = ['VISIT_NO',"STATE_CODE",'STATE_CODE_EXP',
                                 "SHRP_ID",'CONSTRUCTION_NO','VISIT_DATE',"YEAR","MERRA_ID","IRI",'IMP_DATE','IMP_TYPE_EXP','IMP_THICKNESS'
                                 ,'IRI PREVIOUS','TIME PASSED SINCE LAST REHABILITATION','TIME PASSED FROM PREVIOUS IRI',
                                 "TOTAL_THICKNESS","AC LAYER_THICKNESS","OVERLAY_THICKNESS","TEMP_MEAN_AVG",'FREEZE_INDEX','PRECIPITATION'])
df2 = pd.DataFrame(o2,columns = ["STATE_CODE","SHRP_ID",'CONSTRUCTION_NO',"YEAR", "ANNUAL_ESAL"])

# %%
import numpy as np
import pandas as pd

o1 = pd.read_csv('M3.csv')
o2 = pd.read_csv('esal.csv')

# %%
df1 = pd.DataFrame(o1,columns = ['VISIT_NO','VISIT_DATE',"YEAR","STATE_CODE",'STATE_CODE_EXP',
                                 "SHRP_ID",'CONSTRUCTION_NO',"MERRA_ID","MRI",'IRI0','AGE', "TEMP_MEAN_AVG", 'FREEZE_INDEX','PRECIPITATION'])

# %%
df2 = pd.DataFrame(o2,columns = ["STATE_CODE","SHRP_ID",'CONSTRUCTION_NO',"YEAR", "ANNUAL_ESAL_TREND"])

# %%
df1
# Out:
#      VISIT_NO  VISIT_DATE  YEAR  STATE_CODE STATE_CODE_EXP  SHRP_ID  \
# 0     1100101    8/8/1990  1990           1        Alabama     1001
# 1     1100103   7/28/1992  1992           1        Alabama     1001
# 2     1100104  10/22/1992  1992           1        Alabama     1001
# 3     1100105   1/13/1993  1993           1        Alabama     1001
# 4     1101901    6/5/1990  1990           1        Alabama     1019
# ..        ...         ...   ...         ...            ...      ...
# 958  90641215  10/14/2004  2004          90   Saskatchewan     6412
# 959  90642001   5/31/1990  1990          90   Saskatchewan     6420
# 960  90642002   7/17/1991  1991          90   Saskatchewan     6420
# 961  90642003   8/28/1992  1992          90   Saskatchewan     6420
# 962  90642004   6/12/1993  1993          90   Saskatchewan     6420
#
#      CONSTRUCTION_NO  MERRA_ID   MRI  IRI0    AGE  TEMP_MEAN_AVG  \
# 0                  1    135513  0.86  0.86   0.00             19
# ...

# %%
df2
# Out:
#       STATE_CODE  SHRP_ID  CONSTRUCTION_NO  YEAR  ANNUAL_ESAL_TREND
# 0              1     1001                1  1989             254000
# 1              1     1001                1  1990             241980
# 2              1     1001                1  1991             248810
# 3              1     1001                1  1992             258129
# 4              1     1001                2  1993             111510
# ...          ...      ...              ...   ...                ...
# 7826          90     6420                7  2004              43393
# 7827          90     6420                7  2005              47070
# 7828          90     6420                7  2006              47070
# 7829          90     6420                7  2007              50866
# 7830          90     6420                7  2008              13204
#
# [7831 rows x 5 columns]

# %%
df = df1.merge(df2, on=('STATE_CODE',"SHRP_ID",'CONSTRUCTION_NO',"YEAR"), how='left')

# %%
df
# Out:
#      VISIT_NO  VISIT_DATE  YEAR  STATE_CODE STATE_CODE_EXP  SHRP_ID  \
# 0     1100101    8/8/1990  1990           1        Alabama     1001
# 1     1100103   7/28/1992  1992           1        Alabama     1001
# 2     1100104  10/22/1992  1992           1        Alabama     1001
# 3     1100105   1/13/1993  1993           1        Alabama     1001
# 4     1101901    6/5/1990  1990           1        Alabama     1019
# ..        ...         ...   ...         ...            ...      ...
# 958  90641215  10/14/2004  2004          90   Saskatchewan     6412
# 959  90642001   5/31/1990  1990          90   Saskatchewan     6420
# 960  90642002   7/17/1991  1991          90   Saskatchewan     6420
# 961  90642003   8/28/1992  1992          90   Saskatchewan     6420
# 962  90642004   6/12/1993  1993          90   Saskatchewan     6420
#
#      CONSTRUCTION_NO  MERRA_ID   MRI  IRI0    AGE  TEMP_MEAN_AVG  \
# 0                  1    135513  0.86  0.86   0.00             19
# ...

# %%
#df1.update(df2)

# %%
df.to_csv("M4.csv")
