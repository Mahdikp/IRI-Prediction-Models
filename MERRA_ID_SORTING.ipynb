# %%
import numpy as np
import pandas as pd

o1 = pd.read_csv('OVERLAY4.csv')
o2 = pd.read_csv('merra.csv')

df1 = pd.DataFrame(o1,columns = ['VISIT_NO',"STATE_CODE",'STATE_CODE_EXP',
                                 "SHRP_ID",'CONSTRUCTION_NO','VISIT_DATE',"YEAR","IRI",'IMP_DATE','IMP_TYPE_EXP','IMP_THICKNESS'
                                 ,'IRI PREVIOUS','TIME PASSED SINCE LAST REHABILITATION','TIME PASSED FROM PREVIOUS IRI',
                                 "TOTAL_THICKNESS","AC LAYER_THICKNESS","OVERLAY_THICKNESS","MERRA_ID"])
df2 = pd.DataFrame(o2,columns = ["STATE_CODE","SHRP_ID","MERRA_ID"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-935938d24e91> in <cell line: 4>()
#       2 import pandas as pd
#       3
# ----> 4 o1 = pd.read_csv('OVERLAY4.csv')
#       5 o2 = pd.read_csv('merra.csv')
#       6
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import numpy as np
import pandas as pd

o1 = pd.read_csv('m1.csv')
o2 = pd.read_csv('merra_id.csv')

df1 = pd.DataFrame(o1,columns = ['VISIT_NO','VISIT_DATE',"YEAR","STATE_CODE",'STATE_CODE_EXP',
                                 "SHRP_ID",'CONSTRUCTION_NO','MRI','IRI0',"MERRA_ID"])

df2 = pd.DataFrame(o2,columns = ["STATE_CODE","SHRP_ID","MERRA_ID"])

# %%
df1
# Out:
#      VISIT_NO  VISIT_DATE  YEAR  STATE_CODE STATE_CODE_EXP  SHRP_ID  \
# 0     1100101    8/8/1990  1990           1        Alabama     1001
# 1     1100103   7/28/1992  1992           1        Alabama     1001
# 2     1100104  10/22/1992  1992           1        Alabama     1001
# 3     1100105   1/13/1993  1993           1        Alabama     1001
# 4     1101901    6/5/1990  1990           1        Alabama     1019
# ..        ...         ...   ...         ...            ...      ...
# 958  90641215  10/14/2004  2004          90   Saskatchewan     6412
# 959  90642001   5/31/1990  1990          90   Saskatchewan     6420
# 960  90642002   7/17/1991  1991          90   Saskatchewan     6420
# 961  90642003   8/28/1992  1992          90   Saskatchewan     6420
# 962  90642004   6/12/1993  1993          90   Saskatchewan     6420
#
#      CONSTRUCTION_NO   MRI  IRI0  MERRA_ID
# 0                  1  0.86  0.86       NaN
# 1                  1  0.93  0.86       NaN
# ...

# %%
df2
# Out:
#      STATE_CODE  SHRP_ID  MERRA_ID
# 0             1      101    135513
# 1             1      102    135513
# 2             1      103    135513
# 3             1      104    135513
# 4             1      105    135513
# ..          ...      ...       ...
# 485          89     9018    151661
# 486          90     6405    157945
# 487          90     6410    157942
# 488          90     6412    157942
# 489          90     6420    155645
#
# [490 rows x 3 columns]

# %%
df = df1.merge(df2, on=("STATE_CODE","SHRP_ID"), how='left')

# %%
df
# Out:
#      VISIT_NO  VISIT_DATE  YEAR  STATE_CODE STATE_CODE_EXP  SHRP_ID  \
# 0     1100101    8/8/1990  1990           1        Alabama     1001
# 1     1100103   7/28/1992  1992           1        Alabama     1001
# 2     1100104  10/22/1992  1992           1        Alabama     1001
# 3     1100105   1/13/1993  1993           1        Alabama     1001
# 4     1101901    6/5/1990  1990           1        Alabama     1019
# ..        ...         ...   ...         ...            ...      ...
# 958  90641215  10/14/2004  2004          90   Saskatchewan     6412
# 959  90642001   5/31/1990  1990          90   Saskatchewan     6420
# 960  90642002   7/17/1991  1991          90   Saskatchewan     6420
# 961  90642003   8/28/1992  1992          90   Saskatchewan     6420
# 962  90642004   6/12/1993  1993          90   Saskatchewan     6420
#
#      CONSTRUCTION_NO   MRI  IRI0  MERRA_ID_x  MERRA_ID_y
# 0                  1  0.86  0.86         NaN      135513
# ...

# %%
df1.update(df2)

# %%
df2

# %%
df1.update(df2)

# %%
df1

# %%
df.to_csv("m2.csv")
